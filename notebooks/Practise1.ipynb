# %% [markdown]
# ### First Program

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = input("ya sunan ka? ")

# %%
first = int(input("Enter the first number: "))

# %%
first/2
# Out:
# 35.0
