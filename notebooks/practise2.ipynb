# %%
print (2)
# Out:
# 2

# %%
print("I'm using a single quote in this string!")
# Out:
# I'm using a single quote in this string!

# %%
print("my book,\'qoute' my penn, my bag " + str(2))
# Out:
# my book,'qoute' my penn, my bag 2

# %%
print("hello world! " * 3)
# Out:
# hello world! hello world! hello world!

# %%
example = 32
example = 23
print(example)
# Out:
# 23

# %%
firstName = "abba"
secondName = "baffa"
print(firstName + secondName)
# Out:
# abbabaffa

# %%
print(" " * 10 + "python")
# Out:
#           python

# %%
print(4%3)
# Out:
# 1

# %%
int(6.75)
print('$' + str(6.75))
from math import pi, sqrt
print(pi)
# Out:
# $6.75
# 3.141592653589793
