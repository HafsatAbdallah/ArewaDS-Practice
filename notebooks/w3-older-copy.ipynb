# %% [markdown]
# **** ArewaDS ****

# %%
title = "ArewaDS"
banner = "*" * 6 + "ArewaDS" + "*"*6
banner2 = "*" * 6 + title + "*"*6

print(banner)
print(banner2)
# Out:
# ******ArewaDS******
# ******ArewaDS******

# %%
age = 2
age = str(age)
print("age is " + age)
# Out:
# age is 2

# %%
score = 10
Score = 20
print(score  + Score)
# Out:
# 30

# %%
amount = 12000
vat = amount * 7.5 / 100
print(vat)
# Out:
# Ellipsis
